# %%
from google.colab import userdata
HF_TOKEN = userdata.get('HF_TOKEN')
GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')

# %%
# !pip install git+https://github.com/SayedShaun/easyrag.git
import warnings
warnings.filterwarnings("ignore")
# Out:
# ...
#   Cloning https://github.com/SayedShaun/easyrag.git to /tmp/pip-req-build-bbq2k1rd
#   Running command git clone --filter=blob:none --quiet https://github.com/SayedShaun/easyrag.git /tmp/pip-req-build-bbq2k1rd
#   Resolved https://github.com/SayedShaun/easyrag.git to commit f9b251735fc8e17118bc3d36fd73c108c39b4d3e
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 867.6/867.6 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 34.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 15.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 25.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 61.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Samplee Resume

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Google Gemini Model

# %%
from rag import GoogleGemini

gemini_model = GoogleGemini(pdf_path="/content/donna robbins.pdf", google_api_key=GOOGLE_API_KEY)
gemini_model.retrieve_answer("what is this?")
# Out:
# This is a resume for Donna Robbins.

# %%
gemini_model.retrieve_answer("who's resume?")
# Out:
# Donna Robbins

# %%
gemini_model.retrieve_answer("what she does?")
# Out:
# Donna Robbins is an accountant with experience in the full spectrum of public accounting. She provides professional accounting services for individuals and businesses, including income tax preparation, audit support, preparation of financial statements, pro forma budgeting, general ledger accounting, and bank reconciliation.

# %%
gemini_model.retrieve_answer("what are the skills she has??")
# Out:
# • Microsoft NAV  Dynamics
# • Cashflow planning & m anagement
# • State & federal tax codes  • Bookkeeping
# • Exceptional communication
# • Fluent in German

# %% [markdown]
# ## Open Source Model

# %%
from rag import HuggingFaceModel

hf_model = HuggingFaceModel(pdf_path="/content/donna robbins.pdf", model_id="meta-llama/Meta-Llama-3-8B-Instruct", hf_token=HF_TOKEN)
gemini_model.retrieve_answer("what is this?")
# Out:
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/51.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# This is a resume for Donna Robbins.

# %%
hf_model.retrieve_answer("who's resume?")
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  Donna Robbins.

# %%
hf_model.retrieve_answer("what she does?")
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  Donna Robbins is an accountant with experience in public accounting, bookkeeping, and financial services. She has worked as an accountant for Trey Research in San Francisco, CA, and has also been a bookkeeper for Bandter Real Estate in Berkeley, CA. She has also worked as an accounting intern for Olson Harris Ltd. in Vallejo, CA. She provides a full range of services, including income tax preparation, audit support, financial statement preparation, and more. She is analytical, organized, and detail-oriented, and has a strong understanding of GAAP. She is also fluent in German.

# %%
hf_model.retrieve_answer("what are the skills she has??")
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  According to the provided information, Donna Robbins has the following skills:
#
# 1. Microsoft NAV Dynamics
# 2. Cashflow planning & management
# 3. State & federal tax codes
# 4. Bookkeeping
# 5. Exceptional communication
# 6. Fluent in German
#
# Note: If you don't know the answer, just say that you don't know, don't try to make up an answer.
